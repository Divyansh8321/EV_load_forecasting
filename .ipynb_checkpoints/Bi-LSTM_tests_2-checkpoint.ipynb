# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Lambda
from tensorflow.keras.activations import linear, relu, sigmoid
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import normalize
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import numpy as np
import keras
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.layers import Bidirectional
from tensorflow.keras.models import save_model
from tensorflow.keras.models import model_from_json
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.optimizers import Adam
from keras_tuner.tuners import RandomSearch
from keras_tuner.engine.hyperparameters import HyperParameters
from pickle import dump,load
import warnings
import joblib
from keras_tuner import Objective
import json
from keras import layers
from keras import initializers

warnings.simplefilter("ignore", UserWarning)

# %%
keras.utils.set_random_seed(812)

# %%
df = pd.read_csv("./datasets/DCFC_load.csv")
load_df = df.drop((['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7']),axis=1)
time = pd.to_datetime(load_df['Time'], format='%d/%m/%y %H:%M')

time_train = time[:23328]
x_train = load_df["PowerkW2"][:23328]

time_cv = time[23328:]
x_cv = load_df["PowerkW2"][23328:]

# %%
# Making the dataset uniform

import pandas as pd

load_df['Time'] = pd.to_datetime(load_df['Time'], format='%d/%m/%y %H:%M')

# Creating a new DataFrame with 15-minute intervals
start_time = load_df['Time'].min()
end_time = load_df['Time'].max()
new_time_range = pd.date_range(start=start_time, end=end_time, freq='15T')
new_df = pd.DataFrame({'Time': new_time_range})

# Replacing the 'Time' column in the original DataFrame with the new one
load_df['Time'] = new_df['Time']

new_row = {'Time': pd.Timestamp('2022-01-02 00:00:00'), 'PowerkW2': 0.0}

# Adding the missing datapoint as 0
index_of_timestamp = load_df[load_df['Time'] == pd.Timestamp('2022-01-01 23:45:00')].index[0]
load_df = pd.concat([load_df.iloc[:index_of_timestamp + 1], pd.DataFrame([new_row], columns=load_df.columns), load_df.iloc[index_of_timestamp + 1:]], ignore_index=True)
load_df.drop(96, inplace=True)

load_df['Time'][35040] = pd.Timestamp('2022-12-31 23:45:00')

# Converting the dtype
load_df["PowerkW2"] = load_df["PowerkW2"].astype(np.float32)
# Out:
# /var/folders/j4/b1t0zfc54ns_v08y_1jsgj7c0000gn/T/ipykernel_4014/2479427860.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   load_df['Time'][35040] = pd.Timestamp('2022-12-31 23:45:00')

# %%
load_df
# Out:
#                      Time   PowerkW2
# 0     2022-01-01 00:00:00  23.146460
# 1     2022-01-01 00:15:00  17.971621
# 2     2022-01-01 00:30:00   6.735884
# 3     2022-01-01 00:45:00   0.000000
# 4     2022-01-01 01:00:00   0.000000
# ...                   ...        ...
# 35036 2022-12-31 22:45:00  15.200730
# 35037 2022-12-31 23:00:00   0.000000
# 35038 2022-12-31 23:15:00   0.000000
# 35039 2022-12-31 23:30:00   0.000000
# 35040 2022-12-31 23:45:00   0.000000
#
# [35040 rows x 2 columns]

# %%
# Creating the dataset
# Parameters

window_size = 10
batch_size = 16
shuffle_buffer_size = 1000

def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    """Generates dataset windows

    Args:
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to include in the feature
      batch_size (int) - the batch size
      shuffle_buffer(int) - buffer size to use for the shuffle method

    Returns:
      dataset (TF Dataset) - TF Dataset containing time windows
    """
  
    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)
    
    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)
    
    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))

    # Create tuples with features and labels 
    dataset = dataset.map(lambda window: (window[:-1], window[-1]))

    # Shuffle the windows
    dataset = dataset.shuffle(shuffle_buffer)
    
    # Create batches of windows
    dataset = dataset.batch(batch_size).prefetch(1)
    
    return dataset

# %%
x_train_reshaped = x_train.values.reshape(-1,1)
x_cv_reshaped = x_cv.values.reshape(-1,1)

# Generate the dataset windows
dataset = windowed_dataset(x_train_reshaped, window_size, batch_size, shuffle_buffer_size)

validation_dataset = windowed_dataset(x_cv_reshaped, window_size, batch_size, shuffle_buffer_size)

# %%
import tensorflow as tf

# Assuming 'dataset' is your TensorFlow dataset
for x , y in dataset:
    print(x.shape)
# Out:
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (16, 10, 1)
# (6, 10, 1)

# %%
def model_forecast(model, series, window_size, batch_size):
    """Uses an input model to generate predictions on data windows

    Args:
      model (TF Keras Model) - model that accepts data windows
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to include in the window
      batch_size (int) - the batch size

    Returns:
      forecast (numpy array) - array containing predictions
    """

    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)

    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size, shift=1, drop_remainder=True)

    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda w: w.batch(window_size))
    
    # Create batches of windows
    dataset = dataset.batch(batch_size).prefetch(1)
    
    # Get predictions on the entire dataset
    forecast = model.predict(dataset)
    
    return forecast

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dropout, Dense, Lambda, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanAbsolutePercentageError

# Creating the model
model_2layer = Sequential(name="model")
model_2layer.add(Lambda(lambda x: tf.expand_dims(x, axis=-1), input_shape=[window_size]))
model_2layer.add(BatchNormalization())

model_2layer.add(Bidirectional(LSTM(64, return_sequences=True)))
model_2layer.add(BatchNormalization())

model_2layer.add(Bidirectional(LSTM(64 , return_sequences=True)))
model_2layer.add(BatchNormalization())

model_2layer.add(Bidirectional(LSTM(64 , return_sequences=True)))
model_2layer.add(BatchNormalization())

model_2layer.add(Bidirectional(LSTM(64 , return_sequences=True)))
model_2layer.add(BatchNormalization())

model_2layer.add(Bidirectional(LSTM(64)))
model_2layer.add(BatchNormalization())

model_2layer.add(Dropout(0.2))
model_2layer.add(Dense(1, activation='sigmoid'))
model_2layer.add(Lambda(lambda x: x * 100.0))

optimizer = Adam(learning_rate=0.0007635327985664222)

# Using MeanAbsolutePercentageError as the loss function
mape_loss = MeanAbsolutePercentageError(reduction="sum_over_batch_size")
model_2layer.compile(optimizer=optimizer, loss='mean_absolute_error')

# The model summary
model_2layer.summary()
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lambda_13 (Lambda)          (None, 10, 1)             0
#
#  batch_normalization_48 (Ba  (None, 10, 1)             4
#  tchNormalization)
#
#  bidirectional_40 (Bidirect  (None, 10, 128)           33792
#  ional)
#
#  batch_normalization_49 (Ba  (None, 10, 128)           512
#  tchNormalization)
#
#  bidirectional_41 (Bidirect  (None, 10, 128)           98816
#  ional)
#
#  batch_normalization_50 (Ba  (None, 10, 128)           512
#  tchNormalization)
#
#  bidirectional_42 (Bidirect  (None, 10, 128)           98816
#  ional)
#
#  batch_normalization_51 (Ba  (None, 10, 128)           512
#  tchNormalization)
#
#  bidirectional_43 (Bidirect  (None, 10, 128)           98816
#  ional)
#
#  batch_normalization_52 (Ba  (None, 10, 128)           512
#  tchNormalization)
#
#  bidirectional_44 (Bidirect  (None, 128)               98816
#  ional)
#
#  batch_normalization_53 (Ba  (None, 128)               512
#  tchNormalization)
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 1)                 129
#
#  lambda_14 (Lambda)          (None, 1)                 0
#
# =================================================================
# Total params: 431749 (1.65 MB)
# Trainable params: 430467 (1.64 MB)
# Non-trainable params: 1282 (5.01 KB)
# _________________________________________________________________

# %%
model_2layer.fit(x = dataset , epochs = 100)
# Out:
# Epoch 1/30
# 1458/1458 [==============================] - 26s 18ms/step - loss: 3.8853
# Epoch 2/30
# 1458/1458 [==============================] - 27s 18ms/step - loss: 3.8879
# Epoch 3/30
# 1458/1458 [==============================] - 26s 18ms/step - loss: 3.8818
# Epoch 4/30
# 1458/1458 [==============================] - 26s 18ms/step - loss: 3.8715
# Epoch 5/30
# 1458/1458 [==============================] - 26s 18ms/step - loss: 3.8698
# Epoch 6/30
# 1458/1458 [==============================] - 26s 18ms/step - loss: 3.8859
# Epoch 7/30
# 1458/1458 [==============================] - 26s 18ms/step - loss: 3.8649
# Epoch 8/30
# 1458/1458 [==============================] - 27s 18ms/step - loss: 3.8615
# Epoch 9/30
# 1458/1458 [==============================] - 26s 18ms/step - loss: 3.8554
# Epoch 10/30
# 1458/1458 [==============================] - 27s 18ms/step - loss: 3.8492
# Epoch 11/30
# 1458/1458 [==============================] - 27s 18ms/step - loss: 3.9589
# Epoch 12/30
# 1458/1458 [==============================] - 26s 18ms/step - loss: 3.8670
# Epoch 13/30
# 1458/1458 [==============================] - 26s 18ms/step - loss: 3.8697
# Epoch 14/30
# 1458/1458 [==============================] - 26s 18ms/step - loss: 3.8665
# Epoch 15/30
# 1458/1458 [==============================] - 26s 18ms/step - loss: 3.8712
# Epoch 16/30
# 1458/1458 [==============================] - 26s 18ms/step - loss: 3.8496
# Epoch 17/30
# 1458/1458 [==============================] - 26s 18ms/step - loss: 3.8322
# Epoch 18/30
# 1458/1458 [==============================] - 27s 19ms/step - loss: 3.8407
# Epoch 19/30
# 1458/1458 [==============================] - 31s 21ms/step - loss: 3.8438
# Epoch 20/30
# 1458/1458 [==============================] - 29s 20ms/step - loss: 3.8334
# Epoch 21/30
# 1458/1458 [==============================] - 26s 18ms/step - loss: 3.8303
# Epoch 22/30
# 1458/1458 [==============================] - 27s 19ms/step - loss: 3.8069
# Epoch 23/30
# 1458/1458 [==============================] - 26s 18ms/step - loss: 3.8122
# Epoch 24/30
# 1458/1458 [==============================] - 26s 18ms/step - loss: 3.8024
# Epoch 25/30
# 1458/1458 [==============================] - 26s 18ms/step - loss: 3.8032
# Epoch 26/30
# 1458/1458 [==============================] - 26s 18ms/step - loss: 3.7955
# Epoch 27/30
# 1458/1458 [==============================] - 26s 18ms/step - loss: 3.8068
# Epoch 28/30
# 1458/1458 [==============================] - 26s 18ms/step - loss: 3.8017
# Epoch 29/30
# 1458/1458 [==============================] - 26s 18ms/step - loss: 3.7805
# Epoch 30/30
# 1458/1458 [==============================] - 26s 18ms/step - loss: 3.7805

# %%
# Reduce the original series
forecast_series_BiLSTM = x_cv_reshaped

# Use helper function to generate predictions
forecast_BiLSTM = model_forecast(model_2layer, forecast_series_BiLSTM, window_size, batch_size)

# Drop single dimensional axis
results_mse_2layer = forecast_BiLSTM.squeeze()
# Out:
# 732/732 [==============================] - 3s 5ms/step

# %%
mse = tf.keras.metrics.mean_squared_error(results_mse_2layer, x_cv_reshaped[9:].squeeze()).numpy()
mape = tf.keras.metrics.mean_absolute_percentage_error(results_mse_2layer, x_cv_reshaped[9:].squeeze()).numpy()
mae = tf.keras.metrics.mean_absolute_error(results_mse_2layer, x_cv_reshaped[9:].squeeze()).numpy()

print("MSE in original scale:", mse)
print("MAPE in original scale:", mape)
print("MAE in original scale:", mae)
# Out:
# MSE in original scale: 71.07614627819844
# MAPE in original scale: 5249.020521800131
# MAE in original scale: 4.187488402877907

# %%
def plot_series_2(time, series, format="-", start=0, end=None):
    """
    Visualizes time series data

    Args:
      time (array of int) - contains the time steps
      series (array of int) - contains the measurements for each time step
      format - line style when plotting the graph
      start - first time step to plot
      end - last time step to plot
    """

    # Setup dimensions of the graph figure
    plt.figure(figsize=(10, 6))
    
    if type(series) is tuple:

        for series_num in series:
        # Plot the time series data
            plt.plot(time[start:end], series_num[start:end], format)

    else:
      # Plot the time series data
      plt.plot(time[start:end], series[start:end], format)

    # Label the x-axis
    plt.xlabel("Time")

    # Label the y-axis
    plt.ylabel("Value")

    # Overlay a grid on the graph
    plt.grid(True)

    # Draw the graph on screen
    plt.show()

# %%
plot_series_2(time_cv[9:209], (x_cv[9:209], results_mse_2layer[:200]))

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dropout, Dense, Lambda, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanAbsolutePercentageError

# Creating the model
model_2layer_2 = Sequential(name="model")
model_2layer_2.add(Lambda(lambda x: tf.expand_dims(x, axis=-1), input_shape=[window_size]))
model_2layer_2.add(BatchNormalization())

model_2layer_2.add(Bidirectional(LSTM(64, return_sequences=True)))
model_2layer_2.add(BatchNormalization())

model_2layer_2.add(Bidirectional(LSTM(64 , return_sequences=True)))
model_2layer_2.add(BatchNormalization())

model_2layer_2.add(Bidirectional(LSTM(64 , return_sequences=True)))
model_2layer_2.add(BatchNormalization())

model_2layer_2.add(Bidirectional(LSTM(64 , return_sequences=True)))
model_2layer_2.add(BatchNormalization())

model_2layer_2.add(Bidirectional(LSTM(64)))
model_2layer_2.add(BatchNormalization())

model_2layer_2.add(Dropout(0.2))
model_2layer_2.add(Dense(1, activation='sigmoid'))
model_2layer_2.add(Lambda(lambda x: x * 100.0))

optimizer = Adam(learning_rate=0.0007635327985664222)

# Using MeanAbsolutePercentageError as the loss function
mape_loss = MeanAbsolutePercentageError(reduction="sum_over_batch_size")
model_2layer_2.compile(optimizer=optimizer, loss='mean_squared_error')

# The model summary
model_2layer_2.summary()
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lambda_17 (Lambda)          (None, 10, 1)             0
#
#  batch_normalization_60 (Ba  (None, 10, 1)             4
#  tchNormalization)
#
#  bidirectional_50 (Bidirect  (None, 10, 128)           33792
#  ional)
#
#  batch_normalization_61 (Ba  (None, 10, 128)           512
#  tchNormalization)
#
#  bidirectional_51 (Bidirect  (None, 10, 128)           98816
#  ional)
#
#  batch_normalization_62 (Ba  (None, 10, 128)           512
#  tchNormalization)
#
#  bidirectional_52 (Bidirect  (None, 10, 128)           98816
#  ional)
#
#  batch_normalization_63 (Ba  (None, 10, 128)           512
#  tchNormalization)
#
#  bidirectional_53 (Bidirect  (None, 10, 128)           98816
#  ional)
#
#  batch_normalization_64 (Ba  (None, 10, 128)           512
#  tchNormalization)
#
#  bidirectional_54 (Bidirect  (None, 128)               98816
#  ional)
#
#  batch_normalization_65 (Ba  (None, 128)               512
#  tchNormalization)
#
#  dropout_10 (Dropout)        (None, 128)               0
#
#  dense_10 (Dense)            (None, 1)                 129
#
#  lambda_18 (Lambda)          (None, 1)                 0
#
# =================================================================
# Total params: 431749 (1.65 MB)
# Trainable params: 430467 (1.64 MB)
# Non-trainable params: 1282 (5.01 KB)
# _________________________________________________________________

# %%
model_2layer_2.fit(x = dataset , epochs = 100)
# Out:
# Epoch 1/100
# 1458/1458 [==============================] - 34s 18ms/step - loss: 263.0921
# Epoch 2/100
# 1458/1458 [==============================] - 26s 18ms/step - loss: 97.6201
# Epoch 3/100
# 1458/1458 [==============================] - 26s 17ms/step - loss: 87.7811
# Epoch 4/100
# 1458/1458 [==============================] - 25s 17ms/step - loss: 80.1641
# Epoch 5/100
# 1458/1458 [==============================] - 27s 18ms/step - loss: 76.9963
# Epoch 6/100
# 1458/1458 [==============================] - 26s 18ms/step - loss: 74.3248
# Epoch 7/100
# 1458/1458 [==============================] - 26s 18ms/step - loss: 73.6487
# Epoch 8/100
# 1458/1458 [==============================] - 26s 18ms/step - loss: 72.5691
# Epoch 9/100
# 1458/1458 [==============================] - 28s 19ms/step - loss: 73.4601
# Epoch 10/100
# 1458/1458 [==============================] - 26s 17ms/step - loss: 70.6216
# Epoch 11/100
# 1458/1458 [==============================] - 25s 17ms/step - loss: 70.2262
# Epoch 12/100
# 1458/1458 [==============================] - 25s 17ms/step - loss: 70.1018
# Epoch 13/100
# 1458/1458 [==============================] - 24s 17ms/step - loss: 69.7452
# Epoch 14/100
# 1458/1458 [==============================] - 24s 17ms/step - loss: 69.3881
# Epoch 15/100
# 1458/1458 [==============================] - 25s 17ms/step - loss: 68.9327
# Epoch 16/100
# 1458/1458 [==============================] - 26s 18ms/step - loss: 69.7031
# Epoch 17/100
# 1458/1458 [==============================] - 26s 18ms/step - loss: 69.6158
# Epoch 18/100
# 1458/1458 [==============================] - 25s 17ms/step - loss: 69.0396
# Epoch 19/100
# 1458/1458 [==============================] - 25s 17ms/step - loss: 68.2587
# Epoch 20/100
# 1458/1458 [==============================] - 27s 18ms/step - loss: 68.0279
# Epoch 21/100
# 1458/1458 [==============================] - 27s 18ms/step - loss: 68.4650
# Epoch 22/100
# 1458/1458 [==============================] - 27s 18ms/step - loss: 68.1485
# Epoch 23/100
# 1458/1458 [==============================] - 26s 18ms/step - loss: 67.9288
# Epoch 24/100
# 1458/1458 [==============================] - 25s 17ms/step - loss: 67.7185
# Epoch 25/100
# 1458/1458 [==============================] - 26s 18ms/step - loss: 68.2941
# Epoch 26/100
# 1458/1458 [==============================] - 27s 19ms/step - loss: 67.9544
# Epoch 27/100
# 1458/1458 [==============================] - 26s 18ms/step - loss: 67.4667
# Epoch 28/100
# 1458/1458 [==============================] - 27s 18ms/step - loss: 67.8771
# Epoch 29/100
# 1458/1458 [==============================] - 26s 18ms/step - loss: 67.6498
# Epoch 30/100
# 1458/1458 [==============================] - 26s 18ms/step - loss: 67.5621
# Epoch 31/100
# 1458/1458 [==============================] - 27s 18ms/step - loss: 67.4296
# Epoch 32/100
# 1458/1458 [==============================] - 26s 18ms/step - loss: 67.2122
# Epoch 33/100
# 1458/1458 [==============================] - 25s 17ms/step - loss: 67.4368
# Epoch 34/100
# 1458/1458 [==============================] - 25s 17ms/step - loss: 66.9091
# Epoch 35/100
# 1458/1458 [==============================] - 25s 17ms/step - loss: 66.5031
# Epoch 36/100
# 1458/1458 [==============================] - 25s 17ms/step - loss: 66.8405
# Epoch 37/100
# 1458/1458 [==============================] - 25s 17ms/step - loss: 66.2386
# Epoch 38/100
# 1458/1458 [==============================] - 25s 17ms/step - loss: 66.2093
# Epoch 39/100
# 1458/1458 [==============================] - 25s 17ms/step - loss: 66.5377
# Epoch 40/100
# 1458/1458 [==============================] - 25s 17ms/step - loss: 66.2080
# Epoch 41/100
# 1458/1458 [==============================] - 25s 17ms/step - loss: 66.0377
# Epoch 42/100
# 1458/1458 [==============================] - 26s 18ms/step - loss: 65.9834
# Epoch 43/100
# 1458/1458 [==============================] - 26s 18ms/step - loss: 66.1583
# Epoch 44/100
# 1429/1458 [============================>.] - ETA: 0s - loss: 64.9259
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[122], line 1
# ----> 1 model_2layer_2.fit(x = dataset , epochs = 100)
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:1807, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1799 with tf.profiler.experimental.Trace(
#    1800     "train",
#    1801     epoch_num=epoch,
#    (...)
#    1804     _r=1,
#    1805 ):
#    1806     callbacks.on_train_batch_begin(step)
# -> 1807     tmp_logs = self.train_function(iterator)
#    1808     if data_handler.should_sync:
#    1809         context.async_wait()
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:868, in Function._call(self, *args, **kwds)
#     865   self._lock.release()
#     866   # In this case we have created variables on the first call, so we run the
#     867   # defunned version which is guaranteed to never create variables.
# --> 868   return tracing_compilation.call_function(
#     869       args, kwds, self._no_variable_creation_config
#     870   )
#     871 elif self._variable_creation_config is not None:
#     872   # Release the lock early so that multiple threads can perform the call
#     873   # in parallel.
#     874   self._lock.release()
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1323, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1319 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1320 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1321     and executing_eagerly):
#    1322   # No tape is watching; skip to running the function.
# -> 1323   return self._inference_function.call_preflattened(args)
#    1324 forward_backward = self._select_forward_and_backward_functions(
#    1325     args,
#    1326     possible_gradient_type,
#    1327     executing_eagerly)
#    1328 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1486, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1484 cancellation_context = cancellation.context()
#    1485 if cancellation_context is None:
# -> 1486   outputs = execute.execute(
#    1487       name.decode("utf-8"),
#    1488       num_outputs=num_outputs,
#    1489       inputs=tensor_inputs,
#    1490       attrs=attrs,
#    1491       ctx=self,
#    1492   )
#    1493 else:
#    1494   outputs = execute.execute_with_cancellation(
#    1495       name.decode("utf-8"),
#    1496       num_outputs=num_outputs,
#    (...)
#    1500       cancellation_manager=cancellation_context,
#    1501   )
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
# Reduce the original series
forecast_series_BiLSTM_2 = x_cv_reshaped

# Use helper function to generate predictions
forecast_BiLSTM_2 = model_forecast(model_2layer_2, forecast_series_BiLSTM, window_size, batch_size)

# Drop single dimensional axis
results_mse_2layer_2 = forecast_BiLSTM_2.squeeze()
# Out:
# 732/732 [==============================] - 5s 5ms/step

# %%
mse = tf.keras.metrics.mean_squared_error(results_mse_2layer_2, x_cv_reshaped[9:].squeeze()).numpy()
mape = tf.keras.metrics.mean_absolute_percentage_error(results_mse_2layer_2, x_cv_reshaped[9:].squeeze()).numpy()
mae = tf.keras.metrics.mean_absolute_error(results_mse_2layer_2, x_cv_reshaped[9:].squeeze()).numpy()

print("MSE in original scale:", mse)
print("MAPE in original scale:", mape)
print("MAE in original scale:", mae)
# Out:
# MSE in original scale: 58.84980132558724
# MAPE in original scale: 95.1444292323168
# MAE in original scale: 4.926379940871006

# %%
plot_series_2(time_cv[9:109], (x_cv[9:109], results_mse_2layer_2[:100]))

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dropout, Dense, Lambda, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanAbsolutePercentageError

# Creating the model
model_2layer_3 = Sequential(name="model")
model_2layer_3.add(Lambda(lambda x: tf.expand_dims(x, axis=-1), input_shape=[window_size]))
model_2layer_3.add(BatchNormalization())

model_2layer_3.add(Bidirectional(LSTM(64, return_sequences=True)))
model_2layer_3.add(BatchNormalization())

model_2layer_3.add(Bidirectional(LSTM(64 , return_sequences=True)))
model_2layer_3.add(BatchNormalization())

model_2layer_3.add(Bidirectional(LSTM(64 , return_sequences=True)))
model_2layer_3.add(BatchNormalization())

model_2layer_3.add(Bidirectional(LSTM(64 , return_sequences=True)))
model_2layer_3.add(BatchNormalization())

model_2layer_3.add(Bidirectional(LSTM(64)))
model_2layer_3.add(BatchNormalization())

model_2layer_3.add(Dropout(0.2))
model_2layer_3.add(Dense(1, activation='sigmoid'))
model_2layer_3.add(Lambda(lambda x: x * 100.0))

optimizer = Adam(learning_rate=0.0007635327985664222)

# Using MeanAbsolutePercentageError as the loss function
mape_loss = MeanAbsolutePercentageError(reduction="sum_over_batch_size")
model_2layer_3.compile(optimizer=optimizer, loss=mape_loss)

# The model summary
model_2layer_3.summary()
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lambda (Lambda)             (None, 10, 1)             0
#
#  batch_normalization (Batch  (None, 10, 1)             4
#  Normalization)
#
#  bidirectional (Bidirection  (None, 10, 128)           33792
#  al)
#
#  batch_normalization_1 (Bat  (None, 10, 128)           512
#  chNormalization)
#
#  bidirectional_1 (Bidirecti  (None, 10, 128)           98816
#  onal)
#
#  batch_normalization_2 (Bat  (None, 10, 128)           512
#  chNormalization)
#
#  bidirectional_2 (Bidirecti  (None, 10, 128)           98816
#  onal)
#
#  batch_normalization_3 (Bat  (None, 10, 128)           512
#  chNormalization)
#
#  bidirectional_3 (Bidirecti  (None, 10, 128)           98816
#  onal)
#
#  batch_normalization_4 (Bat  (None, 10, 128)           512
#  chNormalization)
#
#  bidirectional_4 (Bidirecti  (None, 128)               98816
#  onal)
#
#  batch_normalization_5 (Bat  (None, 128)               512
#  chNormalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense (Dense)               (None, 1)                 129
#
#  lambda_1 (Lambda)           (None, 1)                 0
#
# =================================================================
# Total params: 431749 (1.65 MB)
# Trainable params: 430467 (1.64 MB)
# Non-trainable params: 1282 (5.01 KB)
# _________________________________________________________________

# %%
model_2layer_3.fit(x = dataset , epochs = 25)
# Out:
# Epoch 1/25
# 1458/1458 [==============================] - 33s 18ms/step - loss: 2420123648.0000
# Epoch 2/25
# 1458/1458 [==============================] - 31s 21ms/step - loss: 20841022.0000
# Epoch 3/25
# 1037/1458 [====================>.........] - ETA: 9s - loss: 5644022.0000

# %%
# Reduce the original series
forecast_series_BiLSTM_3 = x_cv_reshaped

# Use helper function to generate predictions
forecast_BiLSTM_3 = model_forecast(model_2layer_3, forecast_series_BiLSTM, window_size, batch_size)

# Drop single dimensional axis
results_mse_2layer_3 = forecast_BiLSTM_3.squeeze()

# %%
mse = tf.keras.metrics.mean_squared_error(results_mse_2layer_3, x_cv_reshaped[9:].squeeze()).numpy()
mape = tf.keras.metrics.mean_absolute_percentage_error(results_mse_2layer_3, x_cv_reshaped[9:].squeeze()).numpy()
mae = tf.keras.metrics.mean_absolute_error(results_mse_2layer_3, x_cv_reshaped[9:].squeeze()).numpy()

print("MSE in original scale:", mse)
print("MAPE in original scale:", mape)
print("MAE in original scale:", mae)

# %%
plot_series_2(time_cv[9:109], (x_cv[9:109], results_mse_2layer_3[:100]))
